# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
def request_webpage(url):
  res = requests.get(url)
  try:
    res.raise_for_status()
  except Exception as exc:
    print('There was a problem with the request: %s' % (exc))
  return res

# %%
coming_soon_page = request_webpage("https://www.justdial.com/kolkata/Starmark-Fitness-Studio-Beside-Navina-Cinema-Hall/033PXX33-XX33-181224140504-P1G8_BZDET?xid=S29sa2F0YSBHeW1z")
# Out:
# There was a problem with the request: 403 Client Error: Forbidden for url: https://www.justdial.com/kolkata/Starmark-Fitness-Studio-Beside-Navina-Cinema-Hall/033PXX33-XX33-181224140504-P1G8_BZDET?xid=S29sa2F0YSBHeW1z

# %%
coming_soon_page.text
# Out:
# '<HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</HEAD><BODY>\n<H1>Access Denied</H1>\n \nYou don\'t have permission to access "http&#58;&#47;&#47;www&#46;justdial&#46;com&#47;kolkata&#47;Starmark&#45;Fitness&#45;Studio&#45;Beside&#45;Navina&#45;Cinema&#45;Hall&#47;033PXX33&#45;XX33&#45;181224140504&#45;P1G8&#95;BZDET&#63;" on this server.<P>\nReference&#32;&#35;18&#46;90991002&#46;1571399036&#46;77338e5\n</BODY>\n</HTML>\n'

# %%
coming_soon_soup = BeautifulSoup(coming_soon_page.text)
print(coming_soon_soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Access Denied
#   </title>
#  </head>
#  <body>
#   <h1>
#    Access Denied
#   </h1>
#   You don't have permission to access "http://www.justdial.com/kolkata/Starmark-Fitness-Studio-Beside-Navina-Cinema-Hall/033PXX33-XX33-181224140504-P1G8_BZDET?" on this server.
#   <p>
#    Reference #18.90991002.1571399036.77338e5
#   </p>
#  </body>
# </html>

# %%
details = coming_soon_soup.find('div', attrs = {'class': 'row'})
print(details.pretify)
image_details = details.find_all('picture')
# print(image_details)

#this list comprehension will get all the 'src' data (urls) of the posters,
#while filter out icons for ratings
# image_list = [x['src'] for x in image_details if 'poster' in x['class']]
# image_list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-5a7a527bd2b4> in <module>()
#       1 details = coming_soon_soup.find('div', attrs = {'class': 'row'})
# ----> 2 print(details.pretify)
#       3 image_details = details.find_all('picture')
#       4 # print(image_details)
#       5
#
# AttributeError: 'NoneType' object has no attribute 'pretify'

# %%
image_all_list=[]
for image in image_list:
  image_url = image
  slice_index = image_url.find('_V1_')
  full_size_image_url = image_url[:slice_index] + '_V1_.jpg'
  image_all_list.append(full_size_image_url)

# %%
image_all_list

# %%
for index,single_image in enumerate(image_all_list,0):

  img_res = request_webpage(single_image)
  imageFile = open('MoviePoster'+str(index)+'.jpg', 'wb')
  for chunk in img_res.iter_content(100000):
    imageFile.write(chunk)
  imageFile.close()
